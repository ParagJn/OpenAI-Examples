# %%
#duck db example

import duckdb

conn = duckdb.connect("file.db")

# run the following SQLs
# conn.sql("CREATE TABLE TEST ( COL1 INTEGER)")
conn.sql("INSERT INTO TEST VALUES (124)")
conn.sql("INSERT INTO TEST VALUES (353)")

#show the output of the table
conn.table("TEST").show()

conn.close()    #close the connection
# Out:
# ┌───────┐
# │ COL1  │
# │ int32 │
# ├───────┤
# │   124 │
# │   353 │
# │   124 │
# │   353 │
# │   124 │
# │   353 │
# └───────┘
